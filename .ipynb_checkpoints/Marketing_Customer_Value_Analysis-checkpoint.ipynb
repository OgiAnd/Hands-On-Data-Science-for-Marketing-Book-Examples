# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('Data/WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv')

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# 3           1/20/11       Unemployed      M       0     ...
# 4            2/3/11         Employed      M   43836     ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
list(df.columns)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Response',
#  'Coverage',
#  'Education',
#  'Effective To Date',
#  'EmploymentStatus',
#  'Gender',
#  'Income',
#  'Location Code',
#  'Marital Status',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Total Claim Amount',
#  'Vehicle Class',
#  'Vehicle Size']

# %%
df['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
df['Engaged'] = df['Response'].apply(lambda x: 0 if x=='No' else 1)

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income   ...    \
# 0           2/24/11         Employed      F   56274   ...
# 1           1/31/11       Unemployed      F       0   ...
# 2           2/19/11         Employed      F   48767   ...
# 3           1/20/11       Unemployed      M       0   ...
# 4            2/3/11         Employed      M   43836   ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %% [markdown]
# ### Engagement rate analysis

# %%
engagement_rate_df = pd.DataFrame(df.groupby('Response').count()['Engaged'] / df.shape[0] * 100)

# %%
engagement_rate_df
# Out:
#             Engaged
# Response
# No        85.679877
# Yes       14.320123

# %%
engagement_rate_df.T
# Out:
# Response         No        Yes
# Engaged   85.679877  14.320123

# %% [markdown]
# #### - By Channel

# %%
engagement_by_sales_channel_df = pd.pivot_table(
    df, values='Response', index='Sales Channel', columns='Engaged', aggfunc=len
).fillna(0.0)

engagement_by_sales_channel_df.columns = ['Not Engaged', 'Engaged']

# %%
engagement_by_sales_channel_df
# Out:
#                Not Engaged  Engaged
# Sales Channel
# Agent                 2811      666
# Branch                2273      294
# Call Center           1573      192
# Web                   1169      156

# %% [markdown]
# ### Pie chart - change the color

# %%
engagement_by_sales_channel_df.plot(
    kind='pie',
    figsize=(15, 7),
    startangle=90,
    subplots=True,
    autopct=lambda x: '%0.1f%%' % x
)

plt.show()

# %% [markdown]
# ### Add chart explanation

# %% [markdown]
# ### Modeling - Logistic Regression

# %%
import statsmodels.formula.api as sm

# %%
df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
continuous_vars = [
    'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 
    'Months Since Last Claim', 'Months Since Policy Inception', 
    'Number of Open Complaints', 'Number of Policies', 
    'Total Claim Amount'
]

# %% [markdown]
# ### Convert categorical variables to numbers

# %% [markdown]
# ### Add Why?

# %%
gender_values, gender_labels = df['Gender'].factorize()
df['GenderFactorized'] = gender_values

# %%
gender_values
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
gender_labels
# Out:
# Index(['F', 'M'], dtype='object')

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income       ...         \
# 0           2/24/11         Employed      F   56274       ...
# 1           1/31/11       Unemployed      F       0       ...
# 2           2/19/11         Employed      F   48767       ...
# 3           1/20/11       Unemployed      M       0       ...
# 4            2/3/11         Employed      M   43836       ...
#
#   Number of Policies     Policy Type        Policy  Renew Offer Type  \
# ...

# %%
categories = pd.Categorical(
    df['Education'], 
    categories=['High School or Below', 'Bachelor', 'College', 'Master', 'Doctor']
)

# %%
categories.codes
# Out:
# array([1, 1, 1, ..., 1, 2, 2], dtype=int8)

# %%
categories.categories
# Out:
# Index(['High School or Below', 'Bachelor', 'College', 'Master', 'Doctor'], dtype='object')

# %%
df['EducationFactorized'] = categories.codes

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income         ...          \
# 0           2/24/11         Employed      F   56274         ...
# 1           1/31/11       Unemployed      F       0         ...
# 2           2/19/11         Employed      F   48767         ...
# 3           1/20/11       Unemployed      M       0         ...
# 4            2/3/11         Employed      M   43836         ...
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# ...

# %%
logit = sm.Logit(
    df['Engaged'], 
    df[['Customer Lifetime Value',
        'Income',
        'Monthly Premium Auto',
        'Months Since Last Claim',
        'Months Since Policy Inception',
        'Number of Open Complaints',
        'Number of Policies',
        'Total Claim Amount',
        'GenderFactorized',
        'EducationFactorized'
    ]]
)

# %%
logit_fit = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.420810
#          Iterations 6

# %%
logit_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                Engaged   No. Observations:                 9134
# Model:                          Logit   Df Residuals:                     9124
# Method:                           MLE   Df Model:                            9
# Date:                Mon, 28 Jun 2021   Pseudo R-squ.:                -0.02454
# Time:                        15:45:10   Log-Likelihood:                -3843.7
# converged:                       True   LL-Null:                       -3751.6
#                                         LLR p-value:                     1.000
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Customer Lifetime Value       -6.909e-06   5.03e-06     -1.373      0.170   -1.68e-05    2.96e-06
# ...

# %% [markdown]
# ### Summary Explanation

# %% [markdown]
# By looking at the regression analysis output, we can understand what attributes of customers show significant relationships with customer marketing engagement.
